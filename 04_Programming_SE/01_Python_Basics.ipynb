# %% [markdown]
# # Python Basics for AI
#
# ## Learning Objectives
# - Understand basic Python programming constructs.
# - Write simple Python scripts useful in AI projects.
#
# ## Introduction
# Python is the most popular programming language in AI due to its simplicity and powerful libraries. This notebook covers fundamental Python concepts to get started.

# %% [markdown]
# ## Core Concepts
# - Variables and Data Types
# - Control Flow: if statements, loops
# - Functions: defining and calling
# - Lists and Dictionaries
# - Importing modules
#
# ## Example

# %%
# Simple Python script
def greet(name):
    return f"Hello, {name}! Welcome to AI."

names = ['Alice', 'Bob', 'Charlie']
for name in names:
    print(greet(name))
# Out:
# Hello, Alice! Welcome to AI.
# Hello, Bob! Welcome to AI.
# Hello, Charlie! Welcome to AI.

# %% [markdown]
# ## Exercise
# Write a function to calculate the factorial of a number using a loop.

# %%
# Your code here

# %% [markdown]
# ## Summary
# - Python basics are essential for AI coding.
# - Learn simple scripting before advancing to complex AI libraries.

# %% [markdown]
# ## Further Reading
# - [Official Python Tutorial](https://docs.python.org/3/tutorial/)
# - [Automate the Boring Stuff with Python](https://automatetheboringstuff.com/)
