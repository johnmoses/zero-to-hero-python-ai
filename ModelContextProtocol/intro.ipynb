# %% [markdown]
# # Model Context Protocol (MCP)
#
# This an emerging standard for enabling communication between AI assistants and services. It is used for enhancing the performance of Large Language Models
