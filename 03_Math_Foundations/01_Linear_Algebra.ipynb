# %% [markdown]
# # Linear Algebra Basics
#
# ## Learning Objectives
# - Understand fundamental concepts of linear algebra used in AI.
# - Learn about vectors, matrices, and operations on them.
# - Apply linear algebra to simple numerical examples.
#
# ## Introduction
# Linear algebra is the branch of mathematics concerning vectors, matrices, and linear transformations. It is foundational for many AI algorithms, particularly those involving neural networks and data representation.

# %% [markdown]
# ## Core Concepts
# - **Vectors:** Ordered lists of numbers representing points or directions in space.
# - **Matrices:** 2D arrays of numbers used to represent linear transformations or datasets.
# - **Matrix Operations:** Addition, multiplication, transpose.
# - **Dot Product:** Measures similarity between vectors.
# - **Identity and Zero Matrices:** Special matrices used in calculations.
# - **Matrix Inversion and Determinants:** For solving linear systems.
#
# ## Example
# Basic vector and matrix operations using NumPy.

# %%
import numpy as np

# Define vectors
v1 = np.array([1, 2, 3])
v2 = np.array([4, 5, 6])

# Dot product
dot_product = np.dot(v1, v2)
print(f"Dot Product of v1 and v2: {dot_product}")

# Define matrices
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

# Matrix multiplication
C = np.matmul(A, B)
print("\nMatrix A:")
print(A)
print("\nMatrix B:")
print(B)
print("\nMatrix A x B:")
print(C)

# Identity matrices
I = np.eye(3)
print("\nIdentity Matrix:")
print(I)

# Zero matrix
Z = np.zeros((3, 3))
print("\nZero Matrix:")
print(Z)

# Matrix inversion
A_inv = np.linalg.inv(A)
print("\nInverse of Matrix A:")
print(A_inv)

# Determinant
det_A = np.linalg.det(A)
print(f"\nDeterminant of Matrix A: {det_A}")
print(f"Transpose of Matrix A: {A.T}")
# Out:
# Dot Product of v1 and v2: 32
#
# Matrix A:
# [[1 2]
#  [3 4]]
#
# Matrix B:
# [[5 6]
#  [7 8]]
#
# Matrix A x B:
# [[19 22]
#  [43 50]]
#
# Identity Matrix:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
#
# Zero Matrix:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
#
# Inverse of Matrix A:
# [[-2.   1. ]
#  [ 1.5 -0.5]]
#
# Determinant of Matrix A: -2.0000000000000004
# Transpose of Matrix A: [[1 3]
#  [2 4]]

# %% [markdown]
# ## Exercise
# Calculate the transpose of matrix C and verify if (A x B)^T equals B^T x A^T.

# %%
# Your code here

# %% [markdown]
# ## Summary
# - Linear algebra concepts such as vectors and matrices are essential for AI.
# - Matrix operations underpin data transformations in various AI algorithms.

# %% [markdown]
# ## Further Reading
# - [Linear Algebra - Khan Academy](https://www.khanacademy.org/math/linear-algebra)
# - [NumPy Matrix Operations](https://numpy.org/doc/stable/user/quickstart.html#array-object)
# - [3Blue1Brown Linear Algebra Series](https://www.youtube.com/playlist?list=PLZHQObOWTQDMsr9K-fh7kYnvHFkHk9M)
