# %% [markdown]
# # Image Processing Fundamentals
#
# ## Learning Objectives
# - Learn basic image processing techniques used in computer vision.
# - Understand image transformations, filtering, and feature extraction.
#
# ## Introduction
# Image processing prepares images for analysis by enhancing features, reducing noise, or extracting useful information.

# %% [markdown]
# ## Core Concepts
# - **Image Transformations:** Resizing, cropping, rotating.
# - **Filtering:** Blurring, sharpening.
# - **Feature Detection:** Edges, corners.
# - **Color Space Conversion:** RGB to grayscale, HSV.
#
# ## Example
# Basic image processing with OpenCV.

# %%
import cv2
import matplotlib.pyplot as plt

# Load image
img = cv2.imread('https://upload.wikimedia.org/wikipedia/commons/7/7d/Dog_face.png')

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Resize image
resized = cv2.resize(gray, (100, 100))

# Display
plt.imshow(resized, cmap='gray')
plt.title('Grayscale Resized Image')
plt.axis('off')
plt.show()
# Out:
# [ WARN:0@0.234] global loadsave.cpp:275 findDecoder imread_('https://upload.wikimedia.org/wikipedia/commons/7/7d/Dog_face.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 8
#       5 img = cv2.imread('https://upload.wikimedia.org/wikipedia/commons/7/7d/Dog_face.png')
#       7 # Convert to grayscale
# ----> 8 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#      10 # Resize image
#      11 resized = cv2.resize(gray, (100, 100))
#
# error: OpenCV(4.12.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# ## Exercise
# Apply Gaussian blur and edge detection to the resized image.

# %%
# Your code here

# %% [markdown]
# ## Summary
# - Image processing is foundational for computer vision tasks.
# - Techniques enhance quality and extract meaningful features.

# %% [markdown]
# ## Further Reading
# - [OpenCV Tutorials](https://docs.opencv.org/4.x/d9/df8/tutorial_root.html)
# - [Digital Image Processing - Gonzalez](https://www.pearson.com/us/higher-education/program/Gonzalez-Digital-Image-Processing-4th-Edition/PGM73889.html)
