# %% [markdown]
# # Variational Autoencoders (VAEs)
#
# ## Learning Objectives
# - Understand the probabilistic framework of VAEs.
# - Learn the encoder, decoder, and latent variable components.
#
# ## Introduction
# VAEs learn a probabilistic latent space to generate new samples and reconstruct input data.

# %% [markdown]
# ## Core Concepts
# - **Latent Space:** Encoded representation of data.
# - **Reparameterization Trick:** Allows gradient-based training.
# - **Loss:** Combines reconstruction loss and KL divergence.
#
# ## Example
# Simple VAE encoder and decoder outline.

# %%
import tensorflow as tf
from tensorflow.keras import layers

latent_dim = 2

class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)
        epsilon = tf.random.normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# Encoder
encoder_inputs = layers.Input(shape=(28, 28, 1))
x = layers.Flatten()(encoder_inputs)
x = layers.Dense(128, activation='relu')(x)
z_mean = layers.Dense(latent_dim)(x)
z_log_var = layers.Dense(latent_dim)(x)
z = Sampling()([z_mean, z_log_var])
encoder = tf.keras.Model(encoder_inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
# Out:
# 2025-08-27 18:12:21.200584: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2025-08-27 18:12:21.200606: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2025-08-27 18:12:21.200609: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1756314741.200623  964299 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1756314741.200646  964299 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 20
#      18 z_mean = layers.Dense(latent_dim)(x)
#      19 z_log_var = layers.Dense(latent_dim)(x)
# ---> 20 z = Sampling()([z_mean, z_log_var])
#      21 encoder = tf.keras.Model(encoder_inputs, [z_mean, z_log_var, z], name='encoder')
#      22 encoder.summary()
#
# File ~/miniforge3/envs/mforge312/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# Cell In[1], line 11, in Sampling.call(self, inputs)
#       9 batch = tf.shape(z_mean)[0]
#      10 dim = tf.shape(z_mean)
# ---> 11 epsilon = tf.random.normal(shape=(batch, dim))
#      12 return z_mean + tf.exp(0.5 * z_log_var) * epsilon
#
# ValueError: Exception encountered when calling Sampling.call().
#
# Could not automatically infer the output shape / dtype of 'sampling' (of type Sampling). Either the `Sampling.call()` method is incorrect, or you need to implement the `Sampling.compute_output_spec() / compute_output_shape()` method. Error encountered:
#
# Shapes must be equal rank, but are 0 and 1
# 	From merging shape 0 with other shapes. for '{{node random_normal/shape}} = Pack[N=2, T=DT_INT32, axis=0](strided_slice, Shape_1)' with input shapes: [], [2].
#
# Arguments received by Sampling.call():
#   • args=(['<KerasTensor shape=(None, 2), dtype=float32, sparse=False, ragged=False, name=keras_tensor_3>', '<KerasTensor shape=(None, 2), dtype=float32, sparse=False, ragged=False, name=keras_tensor_4>'],)
#   • kwargs=<class 'inspect._empty'>

# %% [markdown]
# ## Exercise
# Complete the decoder and compile the VAE model for training.

# %%
# Your code here

# %% [markdown]
# ## Summary
# - VAEs offer powerful generative modeling with interpretable latent spaces.
# - Training maximizes the likelihood of data under the model and regularizes latent space.

# %% [markdown]
# ## Further Reading
# - [Kingma & Welling VAE Paper](https://arxiv.org/abs/1312.6114)
# - [VAE Tutorial](https://keras.io/examples/generative/vae/)
