# %% [markdown]
# # Training Challenges with RNNs
#
# ## Learning Objectives
# - Understand the challenges of training RNNs such as vanishing and exploding gradients.
# - Learn strategies to mitigate these issues.
#
# ## Introduction
# RNNs face difficulties in learning long-range dependencies due to vanishing/exploding gradients. Various techniques help address these problems.

# %% [markdown]
# ## Core Challenges
# - **Vanishing gradients:** Gradients shrink exponentially.
# - **Exploding gradients:** Gradients grow exponentially and destabilize learning.
# - **Training instability:** Difficulty in convergence.
#
# ## Mitigation Techniques
# - Gradient clipping.
# - Use LSTM or GRU cells.
# - Careful initialization and normalization.
#
# ## Example
# Applying gradient clipping in TensorFlow.

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(1000, 64),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(1)
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, clipnorm=1.0)
model.compile(optimizer=optimizer, loss='mse')

print('Model compiled with gradient clipping.')
# Out:
# Model compiled with gradient clipping.
# 2025-08-30 17:13:51.253694: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2025-08-30 17:13:51.253719: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2025-08-30 17:13:51.253723: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1756570431.253733  266838 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1756570431.253750  266838 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Exercise
# Experiment with different clipnorm values and observe training behavior.

# %%
# Your code here

# %% [markdown]
# ## Summary
# - Training RNNs is challenging but manageable with proper techniques.
# - Using gated cells and gradient clipping are effective strategies.

# %% [markdown]
# ## Further Reading
# - [Training RNNs - Colah's blog](https://colah.github.io/posts/2015-08-Understanding-LSTMs/)
# - [TensorFlow Gradient Clipping](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam)
