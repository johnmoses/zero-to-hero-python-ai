# %% [markdown]
# # Ensemble Methods
#
# ## Learning Objectives
# - Learn the concept of ensemble learning to improve model accuracy and robustness.
# - Understand Random Forests, AdaBoost, and an overview of XGBoost.
#
# ## Introduction
# Ensemble methods combine multiple models to create a stronger overall predictor. They reduce overfitting and improve generalization.

# %% [markdown]
# ## Core Concepts
# - **Random Forest:** Combines many decision trees trained on different data samples.
# - **AdaBoost:** Boosting method focusing on difficult examples by weighting.
# - **XGBoost:** Optimized gradient boosting framework.
#
# ## Example
# Train and compare Random Forest with single Decision Tree.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, random_state=42)

dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)
acc_dt = accuracy_score(y_test, y_pred_dt)

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
acc_rf = accuracy_score(y_test, y_pred_rf)

print(f"Decision Tree Accuracy: {acc_dt:.2f}")
print(f"Random Forest Accuracy: {acc_rf:.2f}")
# Out:
# Decision Tree Accuracy: 1.00
# Random Forest Accuracy: 1.00

# %% [markdown]
# AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

import matplotlib.pyplot as plt

# Train AdaBoost classifier
ada = AdaBoostClassifier(n_estimators=100, random_state=42)
ada.fit(X_train, y_train)
y_pred_ada = ada.predict(X_test)

# Calculate accuracy
acc_ada = accuracy_score(y_test, y_pred_ada)
print(f"AdaBoost Accuracy: {acc_ada:.2f}")

# Display classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_ada, target_names=iris.target_names))

# Compare accuracies
methods = ['Decision Tree', 'Random Forest', 'AdaBoost']
accuracies = [acc_dt, acc_rf, acc_ada]

# Plot accuracy comparison
plt.figure(figsize=(10, 5))
plt.bar(methods, accuracies)
plt.title('Model Accuracy Comparison')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
for i, v in enumerate(accuracies):
    plt.text(i, v + 0.01, f'{v:.2f}', ha='center')
plt.show()

# Feature importance plot
plt.figure(figsize=(10, 5))
feature_importance = ada.feature_importances_
plt.bar(iris.feature_names, feature_importance)
plt.title('Feature Importance in AdaBoost')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# AdaBoost Accuracy: 0.97
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       1.00      0.91      0.95        11
#    virginica       0.92      1.00      0.96        12
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.97      0.97        38
# weighted avg       0.98      0.97      0.97        38

# %% [markdown]
# XGBoost

# %% [markdown]
# ## Exercise
# Experiment with AdaBoost on the Iris dataset and compare the accuracy.

# %%
# Your code here

# %% [markdown]
# ## Summary
# - Ensembles leverage multiple models to improve predictive power.
# - Random Forests and AdaBoost are popular ensemble techniques.

# %% [markdown]
# ## Further Reading
# - [Random Forests - scikit-learn](https://scikit-learn.org/stable/modules/ensemble.html#random-forests)
# - [AdaBoost Tutorial](https://www.analyticsvidhya.com/blog/2018/06/comprehensive-guide-for-ensemble-models/)
# - [Introduction to XGBoost](https://xgboost.readthedocs.io/en/latest/tutorials/model.html)
