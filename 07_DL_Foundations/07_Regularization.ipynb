# %% [markdown]
# # Regularization Techniques
#
# ## Learning Objectives
# - Understand the role of regularization in preventing overfitting.
# - Learn common regularization methods: L1, L2, Dropout.
#
# ## Introduction
# Regularization helps control model complexity and improves generalization by penalizing large weights or randomly dropping units during training.

# %% [markdown]
# ## Core Concepts
# - **L1 Regularization:** Promotes sparsity by adding absolute value penalties.
# - **L2 Regularization:** Adds squared penalties to reduce weight magnitude.
# - **Dropout:** Randomly drops neurons during training to prevent co-adaptation.
#
# ## Example
# Applying L2 regularization in TensorFlow.

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers

model = tf.keras.Sequential([
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01), input_shape=(10,)),
    layers.Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# /Users/johnmoses/miniforge3/envs/mforge312/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-09-03 16:22:10.031075: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2025-09-03 16:22:10.031102: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2025-09-03 16:22:10.031105: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1756912930.031119  413098 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# ...

# %% [markdown]
# ## Exercise
# Add dropout layers to the model and observe the effect on training.

# %%
# Your code here

# %% [markdown]
# ## Summary
# - Regularization improves the robustness and performance of deep networks.
# - Combining multiple regularization methods often yields better results.

# %% [markdown]
# ## Further Reading
# - [Dropout: A Simple Way to Prevent Neural Networks from Overfitting](https://jmlr.org/papers/v15/srivastava14a.html)
# - [Regularization in Deep Learning](https://towardsdatascience.com/regularization-in-deep-learning-878b9836e5b6)
