# %% [markdown]
# # Capstone Project: Evaluation and Interpretation
#
# ## Learning Objectives
# - Learn evaluation metrics suitable for classification, regression, and other tasks.
# - Understand model interpretability techniques.
#
# ## Introduction
# Evaluating model performance and interpreting results ensures actionable and trustworthy insights.

# %% [markdown]
# ## Common Metrics
# - Accuracy, precision, recall, F1 for classification.
# - MSE, MAE, R2 for regression.
# - Confusion matrices and ROC curves.
#
# ## Interpretation Techniques
# - Feature importance.
# - SHAP and LIME explanations.
#
# ## Example
# Display classification report using scikit-learn.

# %%
from sklearn.metrics import classification_report
import numpy as np

y_true = np.array([0, 1, 1, 0, 1])
y_pred = np.array([0, 1, 0, 0, 1])
report = classification_report(y_true, y_pred)
print(report)

# %% [markdown]
# ## Exercise
# Evaluate your capstone model and interpret predictions.

# %%
# Your evaluation code here

# %% [markdown]
# ## Summary
# - Evaluation and interpretation are critical for real-world impact.

# %% [markdown]
# ## Further Reading
# - [Model Evaluation Metrics](https://scikit-learn.org/stable/modules/model_evaluation.html)
# - [Interpretable Machine Learning Book](https://christophm.github.io/interpretable-ml-book/)
