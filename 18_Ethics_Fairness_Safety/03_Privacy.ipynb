# %% [markdown]
# # Privacy in AI Systems
#
# ## Learning Objectives
# - Understand the privacy risks related to AI and ML data.
# - Learn techniques to enhance privacy such as differential privacy and federated learning.
#
# ## Introduction
# Protecting individual's data privacy is crucial for ethical and legal AI deployments.

# %% [markdown]
# ## Privacy Risks
# - Data leaks from model inversion.
# - Unauthorized data access.
#
# ## Privacy Enhancing Techniques
# - **Differential Privacy:** Adds noise to protect individual data points.
# - **Federated Learning:** Decentralized training without sharing raw data.
#
# ## Example
# Basic illustration of differential privacy noise mechanism.

# %%
import numpy as np

def add_dp_noise(data, epsilon=1.0):
    sensitivity = 1.0
    scale = sensitivity / epsilon
    noise = np.random.laplace(0, scale, data.shape)
    return data + noise

# Example data
data = np.array([10, 20, 30])
noisy_data = add_dp_noise(data)
print("Original ", data)
print("Noisy data with differential privacy:", noisy_data)

# %% [markdown]
# ## Exercise
# Implement a federated learning simulation with multiple data owners.

# %%
# Your code here

# %% [markdown]
# ## Summary
# - Privacy techniques are essential to protect individual data.
# - Methods balance privacy with model utility.

# %% [markdown]
# ## Further Reading
# - [Differential Privacy](https://privacytools.seas.harvard.edu/differential-privacy)
# - [Federated Learning](https://federatedai.org/)
