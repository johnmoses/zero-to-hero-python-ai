# %% [markdown]
# # Sequence Labeling
#
# ## Learning Objectives
# - Understand sequence labeling tasks such as part-of-speech tagging and named entity recognition.
# - Learn common models used for sequence labeling.
#
# ## Introduction
# Sequence labeling assigns labels to each element in a sequence, a fundamental task in NLP applications like syntactic parsing.

# %% [markdown]
# ## Core Concepts
# - **Conditional Random Fields (CRFs):** Probabilistic graphical models for labeling sequences.
# - **Recurrent Models:** LSTMs and GRUs for context awareness.
# - **Evaluation Metrics:** Precision, recall, F1-score.
#
# ## Example
# POS tagging using simple rule-based or pretrained model.

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
sentence = "Natural language processing is fascinating."
tokens = nltk.word_tokenize(sentence)
tags = nltk.pos_tag(tokens)
print(tags)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/johnmoses/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[1], line 5
#       3 sentence = "Natural language processing is fascinating."
#       4 tokens = nltk.word_tokenize(sentence)
# ----> 5 tags = nltk.pos_tag(tokens)
#       6 print(tags)
#
# File ~/miniforge3/envs/mforge312/lib/python3.12/site-packages/nltk/tag/__init__.py:168, in pos_tag(tokens, tagset, lang)
#     143 def pos_tag(tokens, tagset=None, lang="eng"):
#     144     """
#     145     Use NLTK's currently recommended part of speech tagger to
#     146     tag the given list of tokens.
#    (...)    166     :rtype: list(tuple(str, str))
#     167     """
# --> 168     tagger = _get_tagger(lang)
#     169     return _pos_tag(tokens, tagset, tagger, lang)
#
# File ~/miniforge3/envs/mforge312/lib/python3.12/site-packages/nltk/tag/__init__.py:110, in _get_tagger(lang)
#     108     tagger = PerceptronTagger(lang=lang)
#     109 else:
# --> 110     tagger = PerceptronTagger()
#     111 return tagger
#
# File ~/miniforge3/envs/mforge312/lib/python3.12/site-packages/nltk/tag/perceptron.py:183, in PerceptronTagger.__init__(self, load, lang)
#     181 self.classes = set()
#     182 if load:
# --> 183     self.load_from_json(lang)
#
# File ~/miniforge3/envs/mforge312/lib/python3.12/site-packages/nltk/tag/perceptron.py:273, in PerceptronTagger.load_from_json(self, lang)
#     271 def load_from_json(self, lang="eng"):
#     272     # Automatically find path to the tagger if location is not specified.
# --> 273     loc = find(f"taggers/averaged_perceptron_tagger_{lang}/")
#     274     with open(loc + TAGGER_JSONS[lang]["weights"]) as fin:
#     275         self.model.weights = json.load(fin)
#
# File ~/miniforge3/envs/mforge312/lib/python3.12/site-packages/nltk/data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource averaged_perceptron_tagger_eng not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('averaged_perceptron_tagger_eng')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load taggers/averaged_perceptron_tagger_eng/
#
#   Searched in:
#     - '/Users/johnmoses/nltk_data'
#     - '/Users/johnmoses/miniforge3/envs/mforge312/nltk_data'
#     - '/Users/johnmoses/miniforge3/envs/mforge312/share/nltk_data'
#     - '/Users/johnmoses/miniforge3/envs/mforge312/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %% [markdown]
# ## Exercise
# Try named entity recognition with NLTK or SpaCy on a sample text.

# %%
# Your code here

# %% [markdown]
# ## Summary
# - Sequence labeling is vital for understanding linguistic structure.
# - Both probabilistic and neural models are used effectively.

# %% [markdown]
# ## Further Reading
# - [Sequence Labeling - Wikipedia](https://en.wikipedia.org/wiki/Sequence_labeling)
# - [NLTK Book - Tagging](http://www.nltk.org/book/ch05.html)
