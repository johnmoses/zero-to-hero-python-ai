# %% [markdown]
# # Transfer Learning with CNNs
#
# ## Learning Objectives
# - Understand the concept of transfer learning in computer vision.
# - Use pretrained models to improve performance on limited data.
#
# ## Introduction
# Transfer learning leverages knowledge from pretrained models on large datasets to solve similar tasks with less data and faster training.

# %% [markdown]
# ## Core Concepts
# - **Pretrained Models:** Models trained on large datasets like ImageNet.
# - **Fine-tuning:** Adjusting pretrained weights for a new task.
# - **Feature Extraction:** Using pretrained models for feature representations.
#
# ## Example
# Using pretrained MobileNetV2 for a new classification task.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Load pretrained MobileNetV2 without top layer
base_model = tf.keras.applications.MobileNetV2(input_shape=(224, 224, 3),
                                               include_top=False,
                                               weights='imagenet')
base_model.trainable = False  # freeze base

# Add new classification head
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(5, activation='softmax')  # example 5 classes
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 2025-08-28 18:52:57.916356: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2025-08-28 18:52:57.916382: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2025-08-28 18:52:57.916386: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1756403577.916401  995532 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1756403577.916424  995532 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ...

# %% [markdown]
# ## Exercise
# Try unfreezing some layers of the pretrained model and fine-tuning it.

# %%
# Write your code here

# %% [markdown]
# ## Summary
# - Transfer learning reduces training time and data needs.
# - Fine-tuning allows models to adapt pretrained features to new tasks.

# %% [markdown]
# ## Further Reading
# - [TensorFlow Transfer Learning Guide](https://www.tensorflow.org/tutorials/images/transfer_learning)
# - [Transfer Learning in Computer Vision](https://cs231n.github.io/transfer-learning/)
